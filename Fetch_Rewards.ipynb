# %%
# loading libraries
import gzip
import json    
# !pip install --user pandas==1.0.3
import pandas as pd
from pandas.io.json import json_normalize
pd.__version__
import matplotlib.pyplot as plt
import seaborn as sns

file = gzip.open("C:/Users/amals/Downloads/receipts.json.gz", "rb")
data = file.read()
# Out:
# Requirement already satisfied: pandas==1.0.3 in c:\users\amals\appdata\roaming\python\python37\site-packages (1.0.3)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\amals\anaconda3\lib\site-packages (from pandas==1.0.3) (1.16.4)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\amals\anaconda3\lib\site-packages (from pandas==1.0.3) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\amals\anaconda3\lib\site-packages (from pandas==1.0.3) (2019.1)
# Requirement already satisfied: six>=1.5 in c:\users\amals\anaconda3\lib\site-packages (from python-dateutil>=2.6.1->pandas==1.0.3) (1.12.0)
# C:\Users\amals\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Printing data
# data

# %%
# loading receipt data
import pandas as pd
from ast import literal_eval
fn = 'C:/Users/amals/Downloads/receipts.json.gz'
df1 = pd.read_json(fn, lines=True, compression='gzip')
df1 = pd.DataFrame(df1)
df1
# Out:
#                                        _id  bonusPointsEarned  \
# 0     {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1     {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2     {'$oid': '5ff1e1f10a720f052300057a'}                5.0
# 3     {'$oid': '5ff1e1ee0a7214ada100056f'}                5.0
# 4     {'$oid': '5ff1e1d20a7214ada1000561'}                5.0
# ...                                    ...                ...
# 1114  {'$oid': '603cc0630a720fde100003e6'}               25.0
# 1115  {'$oid': '603d0b710a720fde1000042a'}                NaN
# 1116  {'$oid': '603cf5290a720fde10000413'}                NaN
# 1117  {'$oid': '603ce7100a7217c72c000405'}               25.0
# 1118  {'$oid': '603c4fea0a7217c72c000389'}                NaN
#
#                                 bonusPointsEarnedReason  \
# 0     Receipt number 2 completed, bonus point schedu...
# 1     Receipt number 5 completed, bonus point schedu...
# 2                            All-receipts receipt bonus
# 3                            All-receipts receipt bonus
# 4                            All-receipts receipt bonus
# ...                                                 ...
# 1114                        COMPLETE_NONPARTNER_RECEIPT
# 1115                                                NaN
# 1116                                                NaN
# 1117                        COMPLETE_NONPARTNER_RECEIPT
# 1118                                                NaN
#
#                     createDate               dateScanned  \
# 0     {'$date': 1609687531000}  {'$date': 1609687531000}
# 1     {'$date': 1609687483000}  {'$date': 1609687483000}
# 2     {'$date': 1609687537000}  {'$date': 1609687537000}
# 3     {'$date': 1609687534000}  {'$date': 1609687534000}
# 4     {'$date': 1609687506000}  {'$date': 1609687506000}
# ...                        ...                       ...
# 1114  {'$date': 1614594147000}  {'$date': 1614594147000}
# 1115  {'$date': 1614613361873}  {'$date': 1614613361873}
# 1116  {'$date': 1614607657664}  {'$date': 1614607657664}
# 1117  {'$date': 1614604048000}  {'$date': 1614604048000}
# 1118  {'$date': 1614565354962}  {'$date': 1614565354962}
#
#                   finishedDate                modifyDate  \
# 0     {'$date': 1609687531000}  {'$date': 1609687536000}
# 1     {'$date': 1609687483000}  {'$date': 1609687488000}
# 2                          NaN  {'$date': 1609687542000}
# 3     {'$date': 1609687534000}  {'$date': 1609687539000}
# 4     {'$date': 1609687511000}  {'$date': 1609687511000}
# ...                        ...                       ...
# 1114                       NaN  {'$date': 1614594148000}
# 1115                       NaN  {'$date': 1614613361873}
# 1116                       NaN  {'$date': 1614607657664}
# 1117                       NaN  {'$date': 1614604049000}
# 1118                       NaN  {'$date': 1614565354962}
#
#              pointsAwardedDate  pointsEarned              purchaseDate  \
# 0     {'$date': 1609687531000}         500.0  {'$date': 1609632000000}
# 1     {'$date': 1609687483000}         150.0  {'$date': 1609601083000}
# 2                          NaN           5.0  {'$date': 1609632000000}
# 3     {'$date': 1609687534000}           5.0  {'$date': 1609632000000}
# 4     {'$date': 1609687506000}           5.0  {'$date': 1609601106000}
# ...                        ...           ...                       ...
# 1114                       NaN          25.0  {'$date': 1597622400000}
# 1115                       NaN           NaN                       NaN
# 1116                       NaN           NaN                       NaN
# 1117                       NaN          25.0  {'$date': 1597622400000}
# 1118                       NaN           NaN                       NaN
#
#       purchasedItemCount                             rewardsReceiptItemList  \
# 0                    5.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 1                    2.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 2                    1.0  [{'needsFetchReview': False, 'partnerItemId': ...
# 3                    4.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 4                    2.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# ...                  ...                                                ...
# 1114                 2.0  [{'barcode': 'B076FJ92M4', 'description': 'mue...
# 1115                 NaN                                                NaN
# 1116                 NaN                                                NaN
# 1117                 2.0  [{'barcode': 'B076FJ92M4', 'description': 'mue...
# 1118                 NaN                                                NaN
#
#      rewardsReceiptStatus  totalSpent                    userId
# 0                FINISHED       26.00  5ff1e1eacfcf6c399c274ae6
# 1                FINISHED       11.00  5ff1e194b6a9d73a3a9f1052
# 2                REJECTED       10.00  5ff1e1f1cfcf6c399c274b0b
# 3                FINISHED       28.00  5ff1e1eacfcf6c399c274ae6
# 4                FINISHED        1.00  5ff1e194b6a9d73a3a9f1052
# ...                   ...         ...                       ...
# 1114             REJECTED       34.96  5fc961c3b8cfca11a077dd33
# 1115            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1116            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1117             REJECTED       34.96  5fc961c3b8cfca11a077dd33
# 1118            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
#
# [1119 rows x 15 columns]

# %%
# checking data type
df1.dtypes
# Out:
# _id                         object
# bonusPointsEarned          float64
# bonusPointsEarnedReason     object
# createDate                  object
# dateScanned                 object
# finishedDate                object
# modifyDate                  object
# pointsAwardedDate           object
# pointsEarned               float64
# purchaseDate                object
# purchasedItemCount         float64
# rewardsReceiptItemList      object
# rewardsReceiptStatus        object
# totalSpent                 float64
# userId                      object
# dtype: object

# %%
# Normalizing Json format
df1['_id'] = pd.json_normalize(df1['_id'])
df1['createDate'] = pd.json_normalize(df1['createDate'])
df1['dateScanned'] = pd.json_normalize(df1['dateScanned'])
df1['modifyDate'] = pd.json_normalize(df1['modifyDate'])

# %%
df1
# Out:
#                            _id  bonusPointsEarned  \
# 0     5ff1e1eb0a720f0523000575              500.0
# 1     5ff1e1bb0a720f052300056b              150.0
# 2     5ff1e1f10a720f052300057a                5.0
# 3     5ff1e1ee0a7214ada100056f                5.0
# 4     5ff1e1d20a7214ada1000561                5.0
# ...                        ...                ...
# 1114  603cc0630a720fde100003e6               25.0
# 1115  603d0b710a720fde1000042a                NaN
# 1116  603cf5290a720fde10000413                NaN
# 1117  603ce7100a7217c72c000405               25.0
# 1118  603c4fea0a7217c72c000389                NaN
#
#                                 bonusPointsEarnedReason     createDate  \
# 0     Receipt number 2 completed, bonus point schedu...  1609687531000
# 1     Receipt number 5 completed, bonus point schedu...  1609687483000
# 2                            All-receipts receipt bonus  1609687537000
# 3                            All-receipts receipt bonus  1609687534000
# 4                            All-receipts receipt bonus  1609687506000
# ...                                                 ...            ...
# 1114                        COMPLETE_NONPARTNER_RECEIPT  1614594147000
# 1115                                                NaN  1614613361873
# 1116                                                NaN  1614607657664
# 1117                        COMPLETE_NONPARTNER_RECEIPT  1614604048000
# 1118                                                NaN  1614565354962
#
#         dateScanned              finishedDate     modifyDate  \
# 0     1609687531000  {'$date': 1609687531000}  1609687536000
# 1     1609687483000  {'$date': 1609687483000}  1609687488000
# 2     1609687537000                       NaN  1609687542000
# 3     1609687534000  {'$date': 1609687534000}  1609687539000
# 4     1609687506000  {'$date': 1609687511000}  1609687511000
# ...             ...                       ...            ...
# 1114  1614594147000                       NaN  1614594148000
# 1115  1614613361873                       NaN  1614613361873
# 1116  1614607657664                       NaN  1614607657664
# 1117  1614604048000                       NaN  1614604049000
# 1118  1614565354962                       NaN  1614565354962
#
#              pointsAwardedDate  pointsEarned              purchaseDate  \
# 0     {'$date': 1609687531000}         500.0  {'$date': 1609632000000}
# 1     {'$date': 1609687483000}         150.0  {'$date': 1609601083000}
# 2                          NaN           5.0  {'$date': 1609632000000}
# 3     {'$date': 1609687534000}           5.0  {'$date': 1609632000000}
# 4     {'$date': 1609687506000}           5.0  {'$date': 1609601106000}
# ...                        ...           ...                       ...
# 1114                       NaN          25.0  {'$date': 1597622400000}
# 1115                       NaN           NaN                       NaN
# 1116                       NaN           NaN                       NaN
# 1117                       NaN          25.0  {'$date': 1597622400000}
# 1118                       NaN           NaN                       NaN
#
#       purchasedItemCount                             rewardsReceiptItemList  \
# 0                    5.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 1                    2.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 2                    1.0  [{'needsFetchReview': False, 'partnerItemId': ...
# 3                    4.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# 4                    2.0  [{'barcode': '4011', 'description': 'ITEM NOT ...
# ...                  ...                                                ...
# 1114                 2.0  [{'barcode': 'B076FJ92M4', 'description': 'mue...
# 1115                 NaN                                                NaN
# 1116                 NaN                                                NaN
# 1117                 2.0  [{'barcode': 'B076FJ92M4', 'description': 'mue...
# 1118                 NaN                                                NaN
#
#      rewardsReceiptStatus  totalSpent                    userId
# 0                FINISHED       26.00  5ff1e1eacfcf6c399c274ae6
# 1                FINISHED       11.00  5ff1e194b6a9d73a3a9f1052
# 2                REJECTED       10.00  5ff1e1f1cfcf6c399c274b0b
# 3                FINISHED       28.00  5ff1e1eacfcf6c399c274ae6
# 4                FINISHED        1.00  5ff1e194b6a9d73a3a9f1052
# ...                   ...         ...                       ...
# 1114             REJECTED       34.96  5fc961c3b8cfca11a077dd33
# 1115            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1116            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
# 1117             REJECTED       34.96  5fc961c3b8cfca11a077dd33
# 1118            SUBMITTED         NaN  5fc961c3b8cfca11a077dd33
#
# [1119 rows x 15 columns]

# %%
# Checking data type after normalization
df1.dtypes
# Out:
# _id                         object
# bonusPointsEarned          float64
# bonusPointsEarnedReason     object
# createDate                   int64
# dateScanned                  int64
# finishedDate                object
# modifyDate                   int64
# pointsAwardedDate           object
# pointsEarned               float64
# purchaseDate                object
# purchasedItemCount         float64
# rewardsReceiptItemList      object
# rewardsReceiptStatus        object
# totalSpent                 float64
# userId                      object
# dtype: object

# %%
# Loading brand data
import pandas as pd
fn = 'C:/Users/amals/Downloads/brands.json.gz'
df2 = pd.read_json(fn, lines=True, compression='gzip')
df2
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# loading users data
fn = 'C:/Users/amals/Downloads/users.json.gz'
df3 = pd.read_json(fn, lines=True, compression='gzip')
df3
# Out:
#                                       _id  active               createdDate  \
# 0    {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 1    {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 2    {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 3    {'$oid': '5ff1e1eacfcf6c399c274ae6'}    True  {'$date': 1609687530554}
# 4    {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# ..                                    ...     ...                       ...
# 490  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
# 491  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
# 492  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
# 493  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
# 494  {'$oid': '54943462e4b07e684157a532'}    True  {'$date': 1418998882381}
#
#                     lastLogin         role signUpSource state
# 0    {'$date': 1609687537858}     consumer        Email    WI
# 1    {'$date': 1609687537858}     consumer        Email    WI
# 2    {'$date': 1609687537858}     consumer        Email    WI
# 3    {'$date': 1609687530597}     consumer        Email    WI
# 4    {'$date': 1609687537858}     consumer        Email    WI
# ..                        ...          ...          ...   ...
# 490  {'$date': 1614963143204}  fetch-staff          NaN   NaN
# 491  {'$date': 1614963143204}  fetch-staff          NaN   NaN
# 492  {'$date': 1614963143204}  fetch-staff          NaN   NaN
# 493  {'$date': 1614963143204}  fetch-staff          NaN   NaN
# 494  {'$date': 1614963143204}  fetch-staff          NaN   NaN
#
# [495 rows x 7 columns]

# %%
# Normalizing Json format
df3['_id'] = pd.json_normalize(df3['_id'],errors="ignore")
df3['createdDate'] = pd.json_normalize(df3['createdDate'],errors="ignore")

# %%
df3
# Out:
#                           _id  active    createdDate  \
# 0    5ff1e194b6a9d73a3a9f1052    True  1609687444800
# 1    5ff1e194b6a9d73a3a9f1052    True  1609687444800
# 2    5ff1e194b6a9d73a3a9f1052    True  1609687444800
# 3    5ff1e1eacfcf6c399c274ae6    True  1609687530554
# 4    5ff1e194b6a9d73a3a9f1052    True  1609687444800
# ..                        ...     ...            ...
# 490  54943462e4b07e684157a532    True  1418998882381
# 491  54943462e4b07e684157a532    True  1418998882381
# 492  54943462e4b07e684157a532    True  1418998882381
# 493  54943462e4b07e684157a532    True  1418998882381
# 494  54943462e4b07e684157a532    True  1418998882381
#
#                     lastLogin         role signUpSource state
# 0    {'$date': 1609687537858}     consumer        Email    WI
# 1    {'$date': 1609687537858}     consumer        Email    WI
# 2    {'$date': 1609687537858}     consumer        Email    WI
# 3    {'$date': 1609687530597}     consumer        Email    WI
# 4    {'$date': 1609687537858}     consumer        Email    WI
# ..                        ...          ...          ...   ...
# 490  {'$date': 1614963143204}  fetch-staff          NaN   NaN
# 491  {'$date': 1614963143204}  fetch-staff          NaN   NaN
# 492  {'$date': 1614963143204}  fetch-staff          NaN   NaN
# 493  {'$date': 1614963143204}  fetch-staff          NaN   NaN
# 494  {'$date': 1614963143204}  fetch-staff          NaN   NaN
#
# [495 rows x 7 columns]

# %%
# Checking Null values for receipt data
df1.isna().sum()
# Out:
# _id                          0
# bonusPointsEarned          575
# bonusPointsEarnedReason    575
# createDate                   0
# dateScanned                  0
# finishedDate               551
# modifyDate                   0
# pointsAwardedDate          582
# pointsEarned               510
# purchaseDate               448
# purchasedItemCount         484
# rewardsReceiptItemList     440
# rewardsReceiptStatus         0
# totalSpent                 435
# userId                       0
# dtype: int64

# %%
df1.shape[0]
# Out:
# 1119

# %% [markdown]
# ### After Checking Null values for receipt data, we can say that almost 50% of the data related to bonus point, purchase date, Purchase count and total price is missing. There data attributes are critical and import for tracking

# %%
# Checking Null values for users data
df3.isna().sum()
# Out:
# _id              0
# active           0
# createdDate      0
# lastLogin       62
# role             0
# signUpSource    48
# state           56
# dtype: int64

# %%
df3.shape[0]
# Out:
# 495

# %% [markdown]
# ### In user data, almost 10% of the data is missing related to state and signup source

# %% [markdown]
# ## Data Exploration for Receipt Data

# %%
df1.describe()
# Out:
#        bonusPointsEarned    createDate   dateScanned    modifyDate  \
# count         544.000000  1.119000e+03  1.119000e+03  1.119000e+03
# mean          238.893382  1.611800e+12  1.611800e+12  1.611847e+12
# std           299.091731  1.484091e+09  1.484091e+09  1.361576e+09
# min             5.000000  1.604089e+12  1.604089e+12  1.609687e+12
# 25%             5.000000  1.610652e+12  1.610652e+12  1.610660e+12
# 50%            45.000000  1.611941e+12  1.611941e+12  1.611941e+12
# 75%           500.000000  1.612704e+12  1.612704e+12  1.612704e+12
# max           750.000000  1.614641e+12  1.614641e+12  1.614641e+12
#
#        pointsEarned  purchasedItemCount   totalSpent
# count    609.000000           635.00000   684.000000
# mean     585.962890            14.75748    77.796857
# std     1357.166947            61.13424   347.110349
# min        0.000000             0.00000     0.000000
# 25%        5.000000             1.00000     1.000000
# 50%      150.000000             2.00000    18.200000
# 75%      750.000000             5.00000    34.960000
# max    10199.800000           689.00000  4721.950000

# %%
# Counting data for bonusPointsEarned category
df1["bonusPointsEarned"].value_counts()
# Out:
# 5.0      183
# 750.0    119
# 25.0      71
# 45.0      31
# 250.0     31
# 500.0     30
# 150.0     27
# 300.0     26
# 100.0     18
# 27.0       6
# 21.0       1
# 40.0       1
# Name: bonusPointsEarned, dtype: int64

# %%
# Plotting graph for bonusPointsEarned
plt.figure(figsize=(15,7))
plt.hist(df1["bonusPointsEarned"], density=True)
plt.ylabel('Probability')
plt.xlabel('bonusPointsEarned')
# Out:
# C:\Users\amals\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\amals\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# Text(0.5, 0, 'bonusPointsEarned')

# %% [markdown]
# ### We can say that most of the data points are concentrated in between 0-100 bonus Points

# %%
# Counting data for total spent category
df1["totalSpent"].value_counts()
# Out:
# 1.00      172
# 10.00      54
# 28.57      50
# 34.96      44
# 49.95      43
#          ...
# 427.81      1
# 612.95      1
# 271.63      1
# 99.95       1
# 574.65      1
# Name: totalSpent, Length: 94, dtype: int64

# %%
# Plotting graph for total spent
plt.figure(figsize=(15,7))
plt.hist(df1["totalSpent"], density=True)
plt.ylabel('Probability')
plt.xlabel('totalSpent')
# Out:
# Text(0.5, 0, 'totalSpent')

# %% [markdown]
# ### We can say that most of the data points are concentrated in between 0-500 dollars

# %%
# Plotting data based on rewardsReceiptStatus
plt.figure(figsize=(15,7))
sns.boxplot(x="rewardsReceiptStatus", y="bonusPointsEarned",
                 data=df1, linewidth=1, dodge=True)

# %% [markdown]
# ### Here we can say that interquartile range is high. Median bonus points is higher for Flagged receipts, rejected receipt status has only 3 points whereas submitted & pending has zero data points

# %%
# Checking Relation between bonusPointsEarned and total spent
plt.figure(figsize=(15,10))
sns.jointplot(data=df1, x="totalSpent", y="bonusPointsEarned", kind="hex")

# %% [markdown]
# ### Correlation between total spent and bonus point is strong in between 0-50

# %%
# Checking data distribution
sns.pairplot(df1)
# Out:
# C:\Users\amals\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\amals\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
# plotting total spent distribution based on created date
plt.figure(figsize=(15,7))
plt.scatter(df1["createDate"], df1["totalSpent"], Color = 'Orange')

# %% [markdown]
# ### Maximum purchase happened between 1610 and 1614 and Format is unknown. It need to be convered to YYYY-MM-DD format to know the exact timeline.

# %%
# plotting purchased Item Count distribution based on created date
plt.figure(figsize=(15,7))
plt.scatter(df1["createDate"], df1["purchasedItemCount"], Color = 'Orange')

# %%
# plotting bonusPointsEarned distribution based on created date
plt.figure(figsize=(15,7))
plt.scatter(df1["createDate"], df1["bonusPointsEarned"], Color = 'Orange')

# %%
df1.corr()
# Out:
#                     bonusPointsEarned  createDate  dateScanned  modifyDate  \
# bonusPointsEarned            1.000000   -0.210862    -0.210862   -0.177035
# createDate                  -0.210862    1.000000     1.000000    0.937038
# dateScanned                 -0.210862    1.000000     1.000000    0.937038
# modifyDate                  -0.177035    0.937038     0.937038    1.000000
# pointsEarned                 0.440762   -0.133617    -0.133617   -0.107876
# purchasedItemCount           0.337626    0.005496     0.005496    0.004049
# totalSpent                   0.283143    0.018761     0.018761    0.018426
#
#                     pointsEarned  purchasedItemCount  totalSpent
# bonusPointsEarned       0.440762            0.337626    0.283143
# createDate             -0.133617            0.005496    0.018761
# dateScanned            -0.133617            0.005496    0.018761
# modifyDate             -0.107876            0.004049    0.018426
# pointsEarned            1.000000            0.347553    0.375839
# purchasedItemCount      0.347553            1.000000    0.954150
# totalSpent              0.375839            0.954150    1.000000

# %%
#Finding coorelation between variables for receipt data
corrMatrix = df1.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# ### Not strong coorelation between data found

# %% [markdown]
# ## Data exploration for User Data

# %%
#Finding coorelation between variables for user data
corrMatrix = df3.corr()
sns.heatmap(corrMatrix, annot=True)
plt.show()

# %%
# Finding role distribution
plt.figure(figsize=(15,7))
sns.countplot('role', data=df3)

# %%
# Finding signup source distribution
plt.figure(figsize=(15,7))
sns.countplot('signUpSource', data=df3)

# %%
# Finding state distribution wrt active status
plt.figure(figsize=(15,7))
sns.countplot('state', data=df3, hue="active")

# %%
# Finding Active status distribution
plt.figure(figsize=(15,7))
sns.countplot('active', data=df3)
